# %%
10+3
# Out:
# 13

# %%
2*3
# Out:
# 6

# %%
2**3
# Out:
# 8

# %%
x = 12
x
# Out:
# 12

# %%
y = 15
x+y
# Out:
# 27

# %%
"Hola mundo"
# Out:
# 'Hola mundo'

# %%
x = "Hola"
y = "Mundo!"
x + " " + y
# Out:
# 'Hola Mundo!'

# %%
[1, 2, 3, 4, 5, 6]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
[1, 2, 3, 4, 5, 6] + [1, 2, 3, 4, 5, 6]
# Out:
# [1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6]

# %%
lista = [1, 2, 3, 4, 5, 6]

# %%
lista[0]
# Out:
# 1

# %%
lista[-1]
# Out:
# 6

# %%
import numpy as np

# %%
np.array(lista)+10
# Out:
# array([11, 12, 13, 14, 15, 16])

# %%
np.array([[1, 2, 3, 4], [5, 6, 7, 8]]).shape
# Out:
# (2, 4)

# %%
otra_lista = np.array([[1, 2, 3, 4], [5, 6, 7, 8]])
lista_result = otra_lista[0]
lista_result*5
# Out:
# array([ 5, 10, 15, 20])

# %%
import pandas as pd

# %%
sr = pd.Series([10, 9, 8, 7, 6])
sr
# Out:
# 0    10
# 1     9
# 2     8
# 3     7
# 4     6
# dtype: int64

# %%
sr.values
# Out:
# array([10,  9,  8,  7,  6])

# %%
sr.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
sr.shape
# Out:
# (5,)

# %%
sr[0]
# Out:
# 10

# %%
sr[[0, 4, 2]]
# Out:
# 0    10
# 4     6
# 2     8
# dtype: int64

# %%
sr = pd.Series([10, 9, 8, 7, 6], index = ['a', 'b', 'c', 'd', 'e'])
sr
# Out:
# a    10
# b     9
# c     8
# d     7
# e     6
# dtype: int64

# %%
Usuario = pd.Series(["Abisai", "Antonio Madera", 24, "México"], index=["Nombre", "Apellidos", "Edad", "País"])
Usuario
# Out:
# Nombre               Abisai
# Apellidos    Antonio Madera
# Edad                     24
# País                 México
# dtype: object

# %%
Usuario["Nombre"]
# Out:
# 'Abisai'

# %%
dict_data = {'Co':100, 'Mx':200, 'Ar':300}
dict_data
# Out:
# {'Ar': 300, 'Co': 100, 'Mx': 200}

# %%
dict_data.keys()
# Out:
# dict_keys(['Co', 'Mx', 'Ar'])

# %%
dict_data['Ar']
# Out:
# 300

# %%
pd.Series(dict_data)
# Out:
# Co    100
# Mx    200
# Ar    300
# dtype: int64

# %%
import numpy as np

# %%
np.nan + 10
# Out:
# nan

# %%
sr = pd.Series(dict_data, ['Co', 'Mx', 'Pe'])
sr
# Out:
# Co    100.0
# Mx    200.0
# Pe      NaN
# dtype: float64

# %%
sr.isnull()
# Out:
# Co    False
# Mx    False
# Pe     True
# dtype: bool

# %%
sr.notnull()
# Out:
# Co     True
# Mx     True
# Pe    False
# dtype: bool
