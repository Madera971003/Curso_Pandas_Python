# %%
import pandas as pd

# %%
df = pd.DataFrame({'a': ['w'] * 4 + ['x'] * 3 + ['y'] * 2 + ['z']+['v'], 
                   'b': [1, 1, 1, 1, 2, 2, 2, 3, 3, 4,5]})
df
# Out:
#     a  b
# 0   w  1
# 1   w  1
# 2   w  1
# 3   w  1
# 4   x  2
# 5   x  2
# 6   x  2
# 7   y  3
# 8   y  3
# 9   z  4
# 10  v  5

# %%
df.duplicated() #Sirve para encontrar registros duplicados, sin tomar en cuenta uno de ellos
# Out:
# 0     False
# 1      True
# 2      True
# 3      True
# 4     False
# 5      True
# 6      True
# 7     False
# 8      True
# 9     False
# 10    False
# dtype: bool

# %%
df.duplicated(keep='first') #usar keep='first' para marcar solo la primera ocurrencia o keep='last' para marcar la última
# Out:
# 0     False
# 1      True
# 2      True
# 3      True
# 4     False
# 5      True
# 6      True
# 7     False
# 8      True
# 9     False
# 10    False
# dtype: bool

# %%
df.duplicated(keep='last')
# Out:
# 0      True
# 1      True
# 2      True
# 3     False
# 4      True
# 5      True
# 6     False
# 7      True
# 8     False
# 9     False
# 10    False
# dtype: bool

# %%
df[~ df.duplicated()] #Filtro para obtener los datos no duplicados ~: es la negacion, pera evitar ver los duplicados
#Se puede usar keep con first o last, dependiendo el caso
# Out:
#     a  b
# 0   w  1
# 4   x  2
# 7   y  3
# 9   z  4
# 10  v  5

# %%
df.duplicated(keep=False) #Este muestra cuales registros estan duplicados tomando el original
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9     False
# 10    False
# dtype: bool

# %%
df[df.duplicated(keep=False)] #Muestra los datos de quienes son los duplicados, omitiendo los que no
# Out:
#    a  b
# 0  w  1
# 1  w  1
# 2  w  1
# 3  w  1
# 4  x  2
# 5  x  2
# 6  x  2
# 7  y  3
# 8  y  3

# %%
df.drop_duplicates() #Elimina los registros duplicados; por defecto keep='first'
# Out:
#     a  b
# 0   w  1
# 4   x  2
# 7   y  3
# 9   z  4
# 10  v  5

# %%
df.drop_duplicates(['a'],keep='last') #Eliminar duplicados tomando en cuenta los duplicados en una columna
# Out:
#     a  b
# 3   w  1
# 6   x  2
# 8   y  3
# 9   z  4
# 10  v  5
