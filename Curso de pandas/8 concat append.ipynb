# %%
import pandas as pd
import numpy as np
pd.__version__
# Out:
# '1.1.5'

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
np.set_printoptions(precision=1)

# %%
x1 = np.random.rand(2,5) * 10 #Generacion de datos
x1
# Out:
# array([[3.2, 7.5, 7.7, 9.6, 2.4],
#        [5.5, 9.4, 6.1, 4.6, 3.5]])

# %%
x2 = np.random.rand(2,5) * -1
x2
# Out:
# array([[-0.83, -0.35, -0.18, -0.1 , -0.96],
#        [-0.32, -0.11, -0.25, -0.4 , -0.19]])

# %%
np.concatenate([x1,x2]) #Concatena ambas matrices, creando más filas; numpy
# Out:
# array([[ 3.2,  7.5,  7.7,  9.6,  2.4],
#        [ 5.5,  9.4,  6.1,  4.6,  3.5],
#        [-0.8, -0.3, -0.2, -0.1, -1. ],
#        [-0.3, -0.1, -0.2, -0.4, -0.2]])

# %%
np.concatenate([x1,x2]).shape
# Out:
# (4, 5)

# %%
np.concatenate([x1,x2], axis = 1) #Se concatenan creandose mas columnas; numpy
# Out:
# array([[ 3.2,  7.5,  7.7,  9.6,  2.4, -0.8, -0.3, -0.2, -0.1, -1. ],
#        [ 5.5,  9.4,  6.1,  4.6,  3.5, -0.3, -0.1, -0.2, -0.4, -0.2]])

# %%
np.concatenate([x1,x2], axis = 1).shape
# Out:
# (2, 10)

# %%
s1 = pd.Series(x1[0], index = ['a', 'b', 'c', 'd', 'e']) #Serie de datos con pandas
s1
# Out:
# a   3.20
# b   7.55
# c   7.74
# d   9.61
# e   2.37
# dtype: float64

# %%
s2 = pd.Series(x2[0], index = ['c', 'd', 'e', 'f', 'g'])
s2
# Out:
# c   -0.83
# d   -0.35
# e   -0.18
# f   -0.10
# g   -0.96
# dtype: float64

# %%
pd.concat([s1,s2]) #Se concatenan; pandas
# Out:
# a    3.20
# b    7.55
# c    7.74
# d    9.61
# e    2.37
# c   -0.83
# d   -0.35
# e   -0.18
# f   -0.10
# g   -0.96
# dtype: float64

# %%
pd.concat([s1,s2], axis = 1) #Se concatenan respetando los indices
# Out:
#      0     1
# a 3.20   nan
# b 7.55   nan
# c 7.74 -0.83
# d 9.61 -0.35
# e 2.37 -0.18
# f  nan -0.10
# g  nan -0.96

# %%
#Si no se requiere concatenar con base a los indices, conviene resetearlos
s1.reset_index(drop=True) #Sin la funcion drop quedará existiendo el indice como una columnas
# Out:
# 0   3.20
# 1   7.55
# 2   7.74
# 3   9.61
# 4   2.37
# dtype: float64

# %%
pd.concat([s1.reset_index(drop=True),s2.reset_index(drop=True)], axis = 1)
# Out:
#      0     1
# 0 3.20 -0.83
# 1 7.55 -0.35
# 2 7.74 -0.18
# 3 9.61 -0.10
# 4 2.37 -0.96

# %%
df1 = pd.DataFrame(np.random.rand(3,2)*10, columns=['a', 'b'])
df1
# Out:
#      a    b
# 0 6.12 1.91
# 1 8.83 5.07
# 2 1.77 1.92

# %%
df2 = pd.DataFrame(np.random.rand(3,2)*-1, columns=['a', 'b'], index = [2, 3, 4])
df2
# Out:
#       a     b
# 2 -0.48 -0.81
# 3 -0.16 -0.86
# 4 -0.55 -0.61

# %%
pd.concat([df1, df2]) #Concatenar DataFrame, se repite un indice
# Out:
#       a     b
# 0  6.12  1.91
# 1  8.83  5.07
# 2  1.77  1.92
# 2 -0.48 -0.81
# 3 -0.16 -0.86
# 4 -0.55 -0.61

# %%
pd.concat([df1, df2], axis = 1) #Se concatenan a lo largo de las columnas
# Out:
#      a    b     a     b
# 0 6.12 1.91   nan   nan
# 1 8.83 5.07   nan   nan
# 2 1.77 1.92 -0.48 -0.81
# 3  nan  nan -0.16 -0.86
# 4  nan  nan -0.55 -0.61

# %%
pd.concat([df1, df2], axis = 1, join='inner') #Se concatenan los datos con indices compartidos
# Out:
#      a    b     a     b
# 2 1.77 1.92 -0.48 -0.81

# %%
pd.concat([
           df1.reset_index(drop=True),
           df2.reset_index(drop=True)
           ], axis = 1) #Se resetean los indices para la concatenacion
# Out:
#      a    b     a     b
# 0 6.12 1.91 -0.48 -0.81
# 1 8.83 5.07 -0.16 -0.86
# 2 1.77 1.92 -0.55 -0.61

# %%
df1.append(df2) #Otra forma de concatenar df
# Out:
#       a     b
# 0  6.12  1.91
# 1  8.83  5.07
# 2  1.77  1.92
# 2 -0.48 -0.81
# 3 -0.16 -0.86
# 4 -0.55 -0.61

# %%
df1.append(df2).append(df2) #Concatenacion tras concatenacion
# Out:
#       a     b
# 0  6.12  1.91
# 1  8.83  5.07
# 2  1.77  1.92
# 2 -0.48 -0.81
# 3 -0.16 -0.86
# 4 -0.55 -0.61
# 2 -0.48 -0.81
# 3 -0.16 -0.86
# 4 -0.55 -0.61

# %%
df1.T #Funcion de transpuesta
# Out:
#      0    1    2
# a 6.12 8.83 1.77
# b 1.91 5.07 1.92

# %%
df1.T.append(df1.T).T
# Out:
#      a    b    a    b
# 0 6.12 1.91 6.12 1.91
# 1 8.83 5.07 8.83 5.07
# 2 1.77 1.92 1.77 1.92
