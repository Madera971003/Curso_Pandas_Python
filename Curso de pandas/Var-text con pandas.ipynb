# %%
import pandas as pd
import numpy as np
data = {'names':['Sara Moreno 34',
                 'jUAn GOMez 23',
                 'CArlos mArtinez 89',
                 'Alfredo VelaZques 3',
                 'luis Mora 56',
                 '@freddier #platzi 10',pd.NA]}

# %%
df = pd.DataFrame(data)
df
# Out:
#                   names
# 0        Sara Moreno 34
# 1         jUAn GOMez 23
# 2    CArlos mArtinez 89
# 3   Alfredo VelaZques 3
# 4          luis Mora 56
# 5  @freddier #platzi 10
# 6                  <NA>

# %%
df['names'].str.lower()
# Out:
# 0          sara moreno 34
# 1           juan gomez 23
# 2      carlos martinez 89
# 3     alfredo velazques 3
# 4            luis mora 56
# 5    @freddier #platzi 10
# 6                    <NA>
# Name: names, dtype: object

# %%
df['names'].str.upper()
# Out:
# 0          SARA MORENO 34
# 1           JUAN GOMEZ 23
# 2      CARLOS MARTINEZ 89
# 3     ALFREDO VELAZQUES 3
# 4            LUIS MORA 56
# 5    @FREDDIER #PLATZI 10
# 6                    <NA>
# Name: names, dtype: object

# %%
df['names'].str.capitalize()
# Out:
# 0          Sara moreno 34
# 1           Juan gomez 23
# 2      Carlos martinez 89
# 3     Alfredo velazques 3
# 4            Luis mora 56
# 5    @freddier #platzi 10
# 6                    <NA>
# Name: names, dtype: object

# %%
df['names'].str.len()
# Out:
# 0      14
# 1      13
# 2      18
# 3      19
# 4      12
# 5      20
# 6    <NA>
# Name: names, dtype: object

# %%
df['names'].str.split(' ') #dividir el texto por espacios
# Out:
# 0          [Sara, Moreno, 34]
# 1           [jUAn, GOMez, 23]
# 2      [CArlos, mArtinez, 89]
# 3     [Alfredo, VelaZques, 3]
# 4            [luis, Mora, 56]
# 5    [@freddier, #platzi, 10]
# 6                        <NA>
# Name: names, dtype: object

# %%
df['names'].str.split('#') #dividir el texto por #
# Out:
# 0           [Sara Moreno 34]
# 1            [jUAn GOMez 23]
# 2       [CArlos mArtinez 89]
# 3      [Alfredo VelaZques 3]
# 4             [luis Mora 56]
# 5    [@freddier , platzi 10]
# 6                       <NA>
# Name: names, dtype: object

# %%
df['names'].str[:5] #Seleccion de caracteres
# Out:
# 0    Sara
# 1    jUAn
# 2    CArlo
# 3    Alfre
# 4    luis
# 5    @fred
# 6     <NA>
# Name: names, dtype: object

# %%
df['names'].str[-5:]
# Out:
# 0    no 34
# 1    ez 23
# 2    ez 89
# 3    ues 3
# 4    ra 56
# 5    zi 10
# 6     <NA>
# Name: names, dtype: object

# %%
df['names'].str.replace('Alfredo','Antonio') #Remplazar alguna cadena por otra
# Out:
# 0          Sara Moreno 34
# 1           jUAn GOMez 23
# 2      CArlos mArtinez 89
# 3     Antonio VelaZques 3
# 4            luis Mora 56
# 5    @freddier #platzi 10
# 6                    <NA>
# Name: names, dtype: object

# %%
df['names'].str.findall('ara') #Busaca alguna secuencia de texto en específico
# Out:
# 0    [ara]
# 1       []
# 2       []
# 3       []
# 4       []
# 5       []
# 6     <NA>
# Name: names, dtype: object

# %%
df['names'].str.contains('or') #filtrado con base a una secuencia de texto
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6     <NA>
# Name: names, dtype: object

# %%
df['names'].str.lower().str.count('a') # contar el número de ocurrencias de un caracter en específico
# Out:
# 0       2
# 1       1
# 2       2
# 3       2
# 4       1
# 5       1
# 6    <NA>
# Name: names, dtype: object

# %%
df['names'].str.extract('([0-9]+)', expand=False) #extrae los caracteres numéricos
# Out:
# 0      34
# 1      23
# 2      89
# 3       3
# 4      56
# 5      10
# 6    <NA>
# Name: names, dtype: object

# %%
df['names'].str.replace('@[^\s]+','') #Extraer las menciones "@xxxx" del texto
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.
# 0         Sara Moreno 34
# 1          jUAn GOMez 23
# 2     CArlos mArtinez 89
# 3    Alfredo VelaZques 3
# 4           luis Mora 56
# 5             #platzi 10
# 6                   <NA>
# Name: names, dtype: object

# %%
np.array([10,8,5,0]) * np.array([0,1,6,12])
# Out:
# array([ 0,  8, 30,  0])
